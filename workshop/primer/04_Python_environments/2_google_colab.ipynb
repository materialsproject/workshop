# %% [markdown]
# # Getting started on Colab

# %% [markdown]
# Colab is based on Jupyter, utilizing the same notebook structure, while allowing for quick and easy sharing. Jupyter notebooks can be shared quickly without requiring download or python environment setup.

# %% [markdown]
# ## Navigating the notebook

# %% [markdown]
# As Colab is based on Jupyter, many jupyter shortcuts are available in colab.
# For example:
#
# - Use `Enter` to select and interact with a cell
#
# - Use `Esc` to deselect a cell

# %%
#Try to type something into this box:

# %% [markdown]
# - Run a cell using `Shift+Enter`

# %% [markdown]
# - Add a code cell above using `a` when not interacting with a cell
# - Add a code cell below using `b` when not interacting with a cell

# %% [markdown]
# ## Executing Shell Commands
# Shell commands are useful to

# %% [markdown]
# ## As with jupyter, use the `!` command to execute shell commands

# %%
# !python --version
# Out:
# Python 3.7.11

# %%
# !ls /content/sample_data/
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %% [markdown]
# ## Use `%%bash` to set entire cell to execute as shell commands

# %%
# %%bash
#
# pwd
# which python3
# Out:
# /content
# /usr/bin/python3

# %% [markdown]
# Shell commands can be combined with python code

# %%
files = !pwd
print(files)
# Out:
# ['/content']

# %% [markdown]
# ## Executing Python Code

# %% [markdown]
# Colab environment comes with a number of pre-installed  scientific and machine learning packages such as numpy, scipy, pandas, tensorflow, and pytorch.
#
# We can check the installed python packages using `pip freeze`

# %%
# !pip freeze
# Out:
# absl-py==0.12.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.1.0
# appdirs==1.4.4
# argon2-cffi==20.1.0
# arviz==0.11.2
# astor==0.8.1
# astropy==4.2.1
# astunparse==1.6.3
# async-generator==1.10
# atari-py==0.2.9
# atomicwrites==1.4.0
# attrs==21.2.0
# audioread==2.1.9
# autograd==1.3
# Babel==2.9.1
# backcall==0.2.0
# beautifulsoup4==4.6.3
# bleach==3.3.0
# blis==0.4.1
# bokeh==2.3.3
# Bottleneck==1.3.2
# branca==0.4.2
# bs4==0.0.1
# CacheControl==0.12.6
# cached-property==1.5.2
# cachetools==4.2.2
# catalogue==1.0.0
# certifi==2021.5.30
# cffi==1.14.6
# cftime==1.5.0
# chardet==3.0.4
# charset-normalizer==2.0.2
# click==7.1.2
# cloudpickle==1.3.0
# cmake==3.12.0
# cmdstanpy==0.9.5
# colorcet==2.0.6
# colorlover==0.3.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.3.2
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cufflinks==0.17.3
# cvxopt==1.2.6
# cvxpy==1.0.31
# cycler==0.10.0
# cymem==2.0.5
# Cython==0.29.23
# daft==0.0.4
# dask==2.12.0
# datascience==0.10.6
# debugpy==1.0.0
# decorator==4.4.2
# defusedxml==0.7.1
# descartes==1.1.0
# dill==0.3.4
# distributed==1.25.3
# dlib @ file:///dlib-19.18.0-cp37-cp37m-linux_x86_64.whl
# dm-tree==0.1.6
# docopt==0.6.2
# docutils==0.17.1
# dopamine-rl==1.0.5
# earthengine-api==0.1.272
# easydict==1.9
# ecos==2.0.7.post1
# editdistance==0.5.3
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz
# entrypoints==0.3
# ephem==4.0.0.2
# et-xmlfile==1.1.0
# fa2==0.3.5
# fastai==1.0.61
# fastdtw==0.3.4
# fastprogress==1.0.0
# fastrlock==0.6
# fbprophet==0.7.1
# feather-format==0.4.1
# filelock==3.0.12
# firebase-admin==4.4.0
# fix-yahoo-finance==0.0.22
# Flask==1.1.4
# flatbuffers==1.12
# folium==0.8.3
# future==0.16.0
# gast==0.4.0
# GDAL==2.2.2
# gdown==3.6.4
# gensim==3.6.0
# geographiclib==1.52
# geopy==1.17.0
# gin-config==0.4.0
# glob2==0.7
# google==2.0.3
# google-api-core==1.26.3
# google-api-python-client==1.12.8
# google-auth==1.32.1
# google-auth-httplib2==0.0.4
# google-auth-oauthlib==0.4.4
# google-cloud-bigquery==1.21.0
# google-cloud-bigquery-storage==1.1.0
# google-cloud-core==1.0.3
# google-cloud-datastore==1.8.0
# google-cloud-firestore==1.7.0
# google-cloud-language==1.2.0
# google-cloud-storage==1.18.1
# google-cloud-translate==1.5.0
# google-colab @ file:///colabtools/dist/google-colab-1.0.0.tar.gz
# google-pasta==0.2.0
# google-resumable-media==0.4.1
# googleapis-common-protos==1.53.0
# googledrivedownloader==0.4
# graphviz==0.10.1
# greenlet==1.1.0
# grpcio==1.34.1
# gspread==3.0.1
# gspread-dataframe==3.0.8
# gym==0.17.3
# h5py==3.1.0
# HeapDict==1.0.1
# hijri-converter==2.1.3
# holidays==0.10.5.2
# holoviews==1.14.4
# html5lib==1.0.1
# httpimport==0.5.18
# httplib2==0.17.4
# httplib2shim==0.0.3
# humanize==0.5.1
# hyperopt==0.1.2
# ideep4py==2.0.0.post3
# idna==2.10
# imageio==2.4.1
# imagesize==1.2.0
# imbalanced-learn==0.4.3
# imblearn==0.0
# imgaug==0.2.9
# importlib-metadata==4.6.1
# importlib-resources==5.2.0
# imutils==0.5.4
# inflect==2.1.0
# iniconfig==1.1.1
# install==1.3.4
# intel-openmp==2021.3.0
# intervaltree==2.1.0
# ipykernel==4.10.1
# ipython==5.5.0
# ipython-genutils==0.2.0
# ipython-sql==0.3.9
# ipywidgets==7.6.3
# itsdangerous==1.1.0
# jax==0.2.17
# jaxlib @ https://storage.googleapis.com/jax-releases/cuda110/jaxlib-0.1.69+cuda110-cp37-none-manylinux2010_x86_64.whl
# jdcal==1.4.1
# jedi==0.18.0
# jieba==0.42.1
# Jinja2==2.11.3
# joblib==1.0.1
# jpeg4py==0.1.4
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.3.5
# jupyter-console==5.2.0
# jupyter-core==4.7.1
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==1.0.0
# kaggle==1.5.12
# kapre==0.3.5
# Keras==2.4.3
# keras-nightly==2.5.0.dev2021032900
# Keras-Preprocessing==1.1.2
# keras-vis==0.4.1
# kiwisolver==1.3.1
# korean-lunar-calendar==0.2.1
# librosa==0.8.1
# lightgbm==2.2.3
# llvmlite==0.34.0
# lmdb==0.99
# LunarCalendar==0.0.9
# lxml==4.2.6
# Markdown==3.3.4
# MarkupSafe==2.0.1
# matplotlib==3.2.2
# matplotlib-inline==0.1.2
# matplotlib-venn==0.11.6
# missingno==0.5.0
# mistune==0.8.4
# mizani==0.6.0
# mkl==2019.0
# mlxtend==0.14.0
# more-itertools==8.8.0
# moviepy==0.2.3.5
# mpmath==1.2.1
# msgpack==1.0.2
# multiprocess==0.70.12.2
# multitasking==0.0.9
# murmurhash==1.0.5
# music21==5.5.0
# natsort==5.5.0
# nbclient==0.5.3
# nbconvert==5.6.1
# nbformat==5.1.3
# nest-asyncio==1.5.1
# netCDF4==1.5.7
# networkx==2.5.1
# nibabel==3.0.2
# nltk==3.2.5
# notebook==5.3.1
# numba==0.51.2
# numexpr==2.7.3
# numpy==1.19.5
# nvidia-ml-py3==7.352.0
# oauth2client==4.1.3
# oauthlib==3.1.1
# okgrade==0.4.3
# opencv-contrib-python==4.1.2.30
# opencv-python==4.1.2.30
# openpyxl==2.5.9
# opt-einsum==3.3.0
# osqp==0.6.2.post0
# packaging==21.0
# palettable==3.3.0
# pandas==1.1.5
# pandas-datareader==0.9.0
# pandas-gbq==0.13.3
# pandas-profiling==1.4.1
# pandocfilters==1.4.3
# panel==0.11.3
# param==1.11.1
# parso==0.8.2
# pathlib==1.0.1
# patsy==0.5.1
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==7.1.2
# pip-tools==4.5.1
# plac==1.1.3
# plotly==4.4.1
# plotnine==0.6.0
# pluggy==0.7.1
# pooch==1.4.0
# portpicker==1.3.9
# prefetch-generator==1.0.1
# preshed==3.0.5
# prettytable==2.1.0
# progressbar2==3.38.0
# prometheus-client==0.11.0
# promise==2.3
# prompt-toolkit==1.0.18
# protobuf==3.17.3
# psutil==5.4.8
# psycopg2==2.7.6.1
# ptyprocess==0.7.0
# py==1.10.0
# pyarrow==3.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycocotools==2.0.2
# pycparser==2.20
# pyct==0.4.8
# pydata-google-auth==1.2.0
# pydot==1.3.0
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# pyemd==0.5.1
# pyerfa==2.0.0
# pyglet==1.5.0
# Pygments==2.6.1
# pygobject==3.26.1
# pymc3==3.11.2
# PyMeeus==0.5.11
# pymongo==3.11.4
# pymystem3==0.2.0
# PyOpenGL==3.1.5
# pyparsing==2.4.7
# pyrsistent==0.18.0
# pysndfile==1.3.8
# PySocks==1.7.1
# pystan==2.19.1.1
# pytest==3.6.4
# python-apt==0.0.0
# python-chess==0.23.11
# python-dateutil==2.8.1
# python-louvain==0.15
# python-slugify==5.0.2
# python-utils==2.5.6
# pytz==2018.9
# pyviz-comms==2.1.0
# PyWavelets==1.1.1
# PyYAML==3.13
# pyzmq==22.1.0
# qdldl==0.1.5.post0
# qtconsole==5.1.1
# QtPy==1.9.0
# regex==2019.12.20
# requests==2.23.0
# requests-oauthlib==1.3.0
# resampy==0.2.2
# retrying==1.3.3
# rpy2==3.4.5
# rsa==4.7.2
# scikit-image==0.16.2
# scikit-learn==0.22.2.post1
# scipy==1.4.1
# screen-resolution-extra==0.0.0
# scs==2.1.4
# seaborn==0.11.1
# semver==2.13.0
# Send2Trash==1.7.1
# setuptools-git==1.2
# Shapely==1.7.1
# simplegeneric==0.8.1
# six==1.15.0
# sklearn==0.0
# sklearn-pandas==1.8.0
# smart-open==5.1.0
# snowballstemmer==2.1.0
# sortedcontainers==2.4.0
# SoundFile==0.10.3.post1
# spacy==2.2.4
# Sphinx==1.8.5
# sphinxcontrib-serializinghtml==1.1.5
# sphinxcontrib-websupport==1.2.4
# SQLAlchemy==1.4.20
# sqlparse==0.4.1
# srsly==1.0.5
# statsmodels==0.10.2
# sympy==1.7.1
# tables==3.4.4
# tabulate==0.8.9
# tblib==1.7.0
# tensorboard==2.5.0
# tensorboard-data-server==0.6.1
# tensorboard-plugin-wit==1.8.0
# tensorflow @ file:///tensorflow-2.5.0-cp37-cp37m-linux_x86_64.whl
# tensorflow-datasets==4.0.1
# tensorflow-estimator==2.5.0
# tensorflow-gcs-config==2.5.0
# tensorflow-hub==0.12.0
# tensorflow-metadata==1.1.0
# tensorflow-probability==0.13.0
# termcolor==1.1.0
# terminado==0.10.1
# testpath==0.5.0
# text-unidecode==1.3
# textblob==0.15.3
# Theano-PyMC==1.1.2
# thinc==7.4.0
# tifffile==2021.7.2
# toml==0.10.2
# toolz==0.11.1
# torch @ https://download.pytorch.org/whl/cu102/torch-1.9.0%2Bcu102-cp37-cp37m-linux_x86_64.whl
# torchsummary==1.5.1
# torchtext==0.10.0
# torchvision @ https://download.pytorch.org/whl/cu102/torchvision-0.10.0%2Bcu102-cp37-cp37m-linux_x86_64.whl
# tornado==5.1.1
# tqdm==4.41.1
# traitlets==5.0.5
# tweepy==3.10.0
# typeguard==2.7.1
# typing-extensions==3.7.4.3
# tzlocal==1.5.1
# uritemplate==3.0.1
# urllib3==1.24.3
# vega-datasets==0.9.0
# wasabi==0.8.2
# wcwidth==0.2.5
# webencodings==0.5.1
# Werkzeug==1.0.1
# widgetsnbextension==3.5.1
# wordcloud==1.5.0
# wrapt==1.12.1
# xarray==0.18.2
# xgboost==0.90
# xkit==0.0.0
# xlrd==1.1.0
# xlwt==1.3.0
# yellowbrick==0.9.1
# zict==2.0.0
# zipp==3.5.0

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x='mean(Miles_per_Gallon)',
  y='Origin',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_point().encode(
  x='Horsepower',
  y='Miles_per_Gallon',
  color='Origin'
).interactive()
# Out:
# alt.Chart(...)

# %%
import pandas

df = pandas.read_csv('sample_data/california_housing_train.csv')

# %%
df
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# 0        -114.31     34.19  ...         1.4936             66900.0
# 1        -114.47     34.40  ...         1.8200             80100.0
# 2        -114.56     33.69  ...         1.6509             85700.0
# 3        -114.57     33.64  ...         3.1917             73400.0
# 4        -114.57     33.57  ...         1.9250             65500.0
# ...          ...       ...  ...            ...                 ...
# 16995    -124.26     40.58  ...         2.3571            111400.0
# 16996    -124.27     40.69  ...         2.5179             79000.0
# 16997    -124.30     41.84  ...         3.0313            103600.0
# 16998    -124.30     41.80  ...         1.9797             85800.0
# 16999    -124.35     40.54  ...         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(df[:5000]).mark_bar().encode(
  x=alt.X('median_house_value', bin=True),
  y='count()',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Runtimes

# %% [markdown]
# Each Colab instance (runtime) runs on an individual Virtual Machine(VM).

# %% [markdown]
# To view active sessions, select Runtime > Manage Sessions.
#
# Here you will be able to view all your open notebooks (and terminate them).

# %% [markdown]
# ---
# By Default, Colab instances have access to CPUs, however notebooks have access to GPU and TPU resources.

# %% [markdown]
# To initialize a runtime with a GPU,
#
#
# 1.   Select 'Runtime' > 'Change Runtime Type'
# 2.   Select 'GPU' in the drop down menu and click 'Save'

# %% [markdown]
# We'll test the GPU using the [example](https://colab.research.google.com/notebooks/gpu.ipynb) provided by colab.

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import timeit

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)
  
# We run each op once to warm up; see: https://stackoverflow.com/a/45067900
cpu()
gpu()

# Run the op several times.
print('Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images '
      '(batch x height x width x channel). Sum of ten runs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 2.800848473000002
# GPU (s):
# 0.03377948799999331
# GPU speedup over CPU: 82x

# %% [markdown]
# # Install Conda using conda-colab
# Google Colab does contain a pre-installed version of conda. Conda is a package manager and environment manager.
#
# This will allow you to use conda to install packages

# %%
# !which conda

# %% [markdown]
# To simplify the conda installation, we use [condacolab](https://pypi.org/project/condacolab/).

# %%
# %%timeit -n 1 -r 1
# !pip install -q condacolab
# Out:
# 1 loop, best of 1: 3.06 s per loop

# %%
# %%timeit -n 1 -r 1
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:36
# 🔁 Restarting kernel...
# 1 loop, best of 1: 36.4 s per loop

# %% [markdown]
# After running condacolab.install(), conda and mamba are installed. Conda and Mamba are functionally equivalent, however conda is written in python, whilst Mamba is written in C.
#
# In our lesson, we use Mamba to leverage its speed (as compared to Conda). However, we note that Mamba can be more prone to bugs, as it is relatively new and less popular.

# %%
# !which conda
# !which mamba
# Out:
# /usr/local/bin/conda
# /usr/local/bin/mamba

# %% [markdown]
# For compatibility with colab, we will need to ensure the numpy version is unchanged when we install packages (such as pymatgen).
#
# To identify the numpy version factory installed on colab:

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.19.5

# %% [markdown]
# The current version of numpy is v1.19.5, thus we specify mamba to install this specific version.

# %%
# %%timeit -n 1 -r 1
# !mamba install -q -c conda-forge pymatgen numpy=1.19.5 -y
# Out:
#   Package                Version  Build                       Channel                    Size
# ───────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────────────
#
#   apscheduler              3.7.0  py37h89c1867_0              conda-forge/linux-64      81 KB
#   ase                     3.22.0  pyhd8ed1ab_0                conda-forge/noarch         2 MB
#   beautifulsoup4           4.9.3  pyhb0f4dca_0                conda-forge/noarch        86 KB
#   cftime                   1.5.0  py37h6f94858_0              conda-forge/linux-64     224 KB
#   click                    8.0.1  py37h89c1867_0              conda-forge/linux-64     145 KB
#   curl                    7.75.0  h979ede3_0                  conda-forge/linux-64     147 KB
#   cycler                  0.10.0  py_2                        conda-forge/noarch         9 KB
#   dataclasses                0.8  pyhc8e2a94_1                conda-forge/noarch         7 KB
#   decorator                4.4.2  py_0                        conda-forge/noarch        11 KB
#   double-conversion        3.1.5  he1b5a44_2                  conda-forge/linux-64      85 KB
#   eigen                    3.3.9  h4bd325d_1                  conda-forge/linux-64     970 KB
#   expat                    2.4.1  h9c3ff4c_0                  conda-forge/linux-64     182 KB
#   ffmpeg                   4.3.1  hca11adc_2                  conda-forge/linux-64      92 MB
#   flask                    2.0.1  pyhd8ed1ab_0                conda-forge/noarch        70 KB
#   freetype                2.10.4  h0708190_1                  conda-forge/linux-64     890 KB
#   future                  0.18.2  py37h89c1867_3              conda-forge/linux-64     714 KB
#   gettext                 0.21.0  hf68c758_0                  pkgs/main/linux-64         3 MB
#   giflib                   5.2.1  h516909a_2                  conda-forge/linux-64      80 KB
#   gl2ps                    1.4.2  he06d7ca_0                  conda-forge/linux-64     134 KB
#   glew                     2.1.0  h9c3ff4c_2                  conda-forge/linux-64     647 KB
#   gmp                      6.2.1  h58526e2_0                  conda-forge/linux-64     806 KB
#   gmpy2                  2.1.0b5  py37h025e8b9_0              conda-forge/linux-64     207 KB
#   gnutls                  3.6.15  he1e5248_0                  pkgs/main/linux-64         1 MB
#   hdf4                    4.2.15  h10796ff_3                  conda-forge/linux-64     950 KB
#   hdf5                    1.10.6  nompi_h6a2412b_1114         conda-forge/linux-64       3 MB
#   importlib-metadata       4.6.1  py37h89c1867_0              conda-forge/linux-64      31 KB
#   itsdangerous             2.0.1  pyhd8ed1ab_0                conda-forge/noarch        17 KB
#   jinja2                   3.0.1  pyhd8ed1ab_0                conda-forge/noarch        99 KB
#   jpeg                        9d  h516909a_0                  conda-forge/linux-64     266 KB
#   jsoncpp                  1.9.4  h4bd325d_3                  conda-forge/linux-64     262 KB
#   kiwisolver               1.3.1  py37h2527ec5_1              conda-forge/linux-64      78 KB
#   lame                     3.100  h14c3975_1001               conda-forge/linux-64     498 KB
#   latexcodec               2.0.1  pyh9f0ad1d_0                conda-forge/noarch        18 KB
#   lcms2                     2.12  hddcbb42_0                  conda-forge/linux-64     443 KB
#   libblas                  3.9.0  10_openblas                 conda-forge/linux-64      11 KB
#   libcblas                 3.9.0  10_openblas                 conda-forge/linux-64      11 KB
#   libgfortran-ng           9.3.0  hff62375_19                 conda-forge/linux-64      22 KB
#   libgfortran5             9.3.0  hff62375_19                 conda-forge/linux-64       2 MB
#   libglu                   9.0.0  he1b5a44_1001               conda-forge/linux-64     413 KB
#   libidn2                  2.3.2  h7f98852_0                  conda-forge/linux-64      98 KB
#   liblapack                3.9.0  10_openblas                 conda-forge/linux-64      11 KB
#   libnetcdf                4.7.4  nompi_h56d31a8_107          conda-forge/linux-64       1 MB
#   libogg                   1.3.5  h27cfd23_1                  pkgs/main/linux-64       199 KB
#   libopenblas             0.3.17  pthreads_h8fe5266_1         conda-forge/linux-64       9 MB
#   libpng                  1.6.37  hed695b0_2                  conda-forge/linux-64     359 KB
#   libtasn1                4.16.0  h27cfd23_0                  pkgs/main/linux-64        58 KB
#   libtheora                1.1.1  h7f98852_1005               conda-forge/linux-64     651 KB
#   libtiff                  4.2.0  hbd63e13_2                  conda-forge/linux-64     639 KB
#   libunistring            0.9.10  h14c3975_0                  conda-forge/linux-64       1 MB
#   libuuid                 2.32.1  h14c3975_1000               conda-forge/linux-64      26 KB
#   libvorbis                1.3.7  he1b5a44_0                  conda-forge/linux-64     287 KB
#   libwebp                  1.2.0  h3452ae3_0                  conda-forge/linux-64      85 KB
#   libwebp-base             1.2.0  h7f98852_2                  conda-forge/linux-64     815 KB
#   libxcb                    1.14  h7b6447c_0                  pkgs/main/linux-64       505 KB
#   loguru                   0.5.3  py37hc8dfbb8_2              conda-forge/linux-64      85 KB
#   markupsafe               2.0.1  py37h5e8e339_0              conda-forge/linux-64      22 KB
#   matplotlib-base          3.4.2  py37hdd32ed1_0              conda-forge/linux-64       7 MB
#   monty                 2021.7.8  pyhd8ed1ab_0                conda-forge/noarch        37 KB
#   mpc                      1.1.0  h04dde30_1009               conda-forge/linux-64     105 KB
#   mpfr                     4.0.2  he80fd80_1                  conda-forge/linux-64     648 KB
#   mpmath                   1.2.1  pyhd8ed1ab_0                conda-forge/noarch       437 KB
#   netcdf4                  1.5.6  nompi_py37hf7b6e46_102      conda-forge/linux-64     528 KB
#   nettle                   3.7.3  hbbd107a_1                  pkgs/main/linux-64       809 KB
#   networkx                 2.6.2  pyhd8ed1ab_0                conda-forge/noarch         1 MB
#   numpy                   1.19.5  py37h038b26d_2              conda-forge/linux-64       5 MB
#   olefile                   0.46  pyh9f0ad1d_1                conda-forge/noarch        32 KB
#   openh264                 2.1.1  h780b84a_0                  conda-forge/linux-64       2 MB
#   palettable               3.3.0  py_0                        conda-forge/noarch        86 KB
#   pandas                   1.3.1  py37h219a48f_0              conda-forge/linux-64      13 MB
#   pillow                   8.3.1  py37h5aabda8_0              pkgs/main/linux-64       633 KB
#   plotly                   5.1.0  pyhd8ed1ab_1                conda-forge/noarch         7 MB
#   proj                     7.2.0  h277dcde_2                  conda-forge/linux-64       3 MB
#   pugixml                 1.11.4  h9c3ff4c_0                  conda-forge/linux-64     125 KB
#   pybtex                  0.24.0  py37h89c1867_0              conda-forge/linux-64     305 KB
#   pymatgen            2020.12.31  py37h2527ec5_0              conda-forge/linux-64       3 MB
#   pyparsing                2.4.7  pyh9f0ad1d_0                conda-forge/noarch        60 KB
#   python-dateutil          2.8.2  pyhd8ed1ab_0                conda-forge/noarch       240 KB
#   pytz                    2021.1  pyhd8ed1ab_0                conda-forge/noarch       239 KB
#   pyyaml                   5.4.1  py37h5e8e339_0              conda-forge/linux-64     189 KB
#   ruamel.yaml            0.17.10  py37h5e8e339_0              conda-forge/linux-64     169 KB
#   ruamel.yaml.clib         0.2.2  py37h5e8e339_2              conda-forge/linux-64     171 KB
#   scipy                    1.7.0  py37h29e03ee_1              conda-forge/linux-64      22 MB
#   soupsieve                2.2.1  pyhd3eb1b0_0                pkgs/main/noarch          32 KB
#   spglib                  1.16.1  py37h902c9e0_0              conda-forge/linux-64     610 KB
#   sympy                      1.8  py37h89c1867_0              conda-forge/linux-64      11 MB
#   tabulate                 0.8.9  pyhd8ed1ab_0                conda-forge/noarch        26 KB
#   tbb                     2020.3  hfd86e86_0                  pkgs/main/linux-64         1 MB
#   tbb-devel               2020.3  hfd86e86_0                  pkgs/main/linux-64         1 MB
#   tenacity                 8.0.1  pyhd8ed1ab_0                conda-forge/noarch        21 KB
#   tornado                    6.1  py37h5e8e339_1              conda-forge/linux-64     646 KB
#   typing_extensions     3.10.0.0  pyha770c72_0                conda-forge/noarch        28 KB
#   tzlocal                  2.0.0  py_0                        conda-forge/noarch        17 KB
#   uncertainties            3.1.6  pyhd8ed1ab_0                conda-forge/noarch        76 KB
#   utfcpp                   3.2.1  ha770c72_0                  conda-forge/linux-64      10 KB
#   vtk                      9.0.1  no_osmesa_py37hd45ff58_104  conda-forge/linux-64      36 MB
#   werkzeug                 2.0.1  pyhd8ed1ab_0                conda-forge/noarch       219 KB
#   x264                1!161.3030  h7f98852_1                  conda-forge/linux-64       2 MB
#   xorg-kbproto             1.0.7  h14c3975_1002               conda-forge/linux-64      26 KB
#   xorg-libice             1.0.10  h516909a_0                  conda-forge/linux-64      57 KB
#   xorg-libsm               1.2.3  hd9c2040_1000               conda-forge/linux-64      26 KB
#   xorg-libx11              1.7.2  h7f98852_0                  conda-forge/linux-64     941 KB
#   xorg-libxext             1.3.4  h7f98852_1                  conda-forge/linux-64      54 KB
#   xorg-libxt               1.2.1  h7f98852_2                  conda-forge/linux-64     375 KB
#   xorg-xextproto           7.3.0  h14c3975_1002               conda-forge/linux-64      27 KB
#   xorg-xproto             7.0.31  h14c3975_1007               conda-forge/linux-64      72 KB
#   zipp                     3.5.0  pyhd8ed1ab_0                conda-forge/noarch        12 KB
#
#   Upgrade:
# ───────────────────────────────────────────────────────────────────────────────────────────────
#
#   ca-certificates      2020.12.5  ha878542_0                  installed
#   ca-certificates       2021.7.5  h06a4308_1                  pkgs/main/linux-64       113 KB
#   certifi              2020.12.5  py37h89c1867_1              installed
#   certifi              2021.5.30  py37h89c1867_0              conda-forge/linux-64     141 KB
#   openssl                 1.1.1j  h7f98852_0                  installed
#   openssl                 1.1.1k  h7f98852_0                  conda-forge/linux-64       2 MB
#
#   Summary:
#
#   Install: 106 packages
#   Upgrade: 3 packages
#
#   Total download: 251 MB
#
# ───────────────────────────────────────────────────────────────────────────────────────────────
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# 1 loop, best of 1: 1min 11s per loop

# %% [markdown]
# Installation of pymatgen is complete. We test the install by creating a dummy structure

# %%
from pymatgen.core import Structure, Lattice
lattice = Lattice.cubic(1)
struct = Structure(lattice, species=['Li'], coords=[[0, 0, 0]])

# %%
struct
# Out:
# Structure Summary
# Lattice
#     abc : 1.0 1.0 1.0
#  angles : 90.0 90.0 90.0
#  volume : 1.0
#       A : 1.0 0.0 0.0
#       B : 0.0 1.0 0.0
#       C : 0.0 0.0 1.0
# PeriodicSite: Li (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]

# %% [markdown]
# # Setup environment using conda constructor.
# ---
#
#
# 1.   First, we want to remove our previous installations by resetting our runtime to factory defaults. This process will revert the environment to its original state, removing any added packages or restoring deleted system files.
#   *   Runtime > Factory reset runtime

# %% [markdown]
# 2.   Next, we install conda colab

# %%
# !pip install -q condacolab

# %% [markdown]
# 3.   Finally, we install using the constructor we have built for the workshop.

# %%
import condacolab

conda_constructor = 'https://github.com/sivonxay/workshop/releases/download/v2021.07.21/condacolab-0.1-Linux-x86_64.sh'
condacolab.install_from_url(conda_constructor)
# Out:
# ✨🍰✨ Everything looks OK!

# %%
from pymatgen.core import Structure, Lattice
lattice = Lattice.cubic(1)
struct = Structure(lattice, species=['Li'], coords=[[0, 0, 0]])

# %%
struct
# Out:
# Structure Summary
# Lattice
#     abc : 1.0 1.0 1.0
#  angles : 90.0 90.0 90.0
#  volume : 1.0
#       A : 1.0 0.0 0.0
#       B : 0.0 1.0 0.0
#       C : 0.0 0.0 1.0
# PeriodicSite: Li (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]

# %% [markdown]
# # Building a conda constructor
# To build your own environment constructor (to save time when restarting notebook)
#
# Adapted from this [notebook](https://colab.research.google.com/github/jaimergp/condacolab/blob/main/constructor-example/condacolab_constructor_tutorial.ipynb#scrollTo=-RDpyAYfXk9L)

# %% [markdown]
# 1. Download the templates constructor

# %%
# !wget -q https://raw.githubusercontent.com/jaimergp/condacolab/main/constructor-example/construct.yaml
# !wget -q https://raw.githubusercontent.com/jaimergp/condacolab/main/constructor-example/pip-dependencies.sh

# %% [markdown]
# 2. Modify the construct.yaml as desired. Here, we will add:
#
#   *   numpy 1.19.5
#   *   pymatgen

# %% [markdown]
# 3. Install condacolab, conda, and mamba

# %%
# !pip install -q condacolab

# Install conda and mamba
import condacolab
condacolab.install()

# Install constructor
# !mamba install -q constructor

# %% [markdown]
# 5. Run constructor to build .sh template file

# %%
# !constructor .

# %% [markdown]
# 5. Download .sh constructor and upload to

# %%
from google.colab import files
installer = !ls *-Linux-x86_64.sh
files.download(installer[0])
